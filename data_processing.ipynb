# %%
import pandas as pd
import numpy as np

#importing modules for data processing

# %%
#importing api.py for the data
import API

from API import list_events_today, create_event, get_calendar_service

# %%
#getting the events
service=get_calendar_service()
events = list_events_today(service)

df = pd.json_normalize(events)
# Out:
# Please visit this URL to authorize this application: https://accounts.google.com/o/oauth2/auth?response_type=code&client_id=776620778108-uj4u9n1oiaod9cb8qe8bhtrqjiucjk7o.apps.googleusercontent.com&redirect_uri=http%3A%2F%2Flocalhost%3A60434%2F&scope=https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fcalendar.events&state=y9o9VFme1vSPCtVbnNGN9PCWIfk9RT&code_challenge=nUuV14pZp-PA8WV6KVW_qlUoSnAO1L5rz8RDUE2T03k&code_challenge_method=S256&access_type=offline
#
#  19 events found for 2026-07-29:
#
# 2026-07-29T05:00:00+05:30 - Gym
# 2026-07-29T07:15:00+05:30 - Pooja
# 2026-07-29T07:30:00+05:30 - Breakfast
# 2026-07-29T08:00:00+05:30 - Check mail, plan
# 2026-07-29T09:00:00+05:30 - DeepWork(no internet)-DSA
# 2026-07-29T11:45:00+05:30 - Lunch break
# 2026-07-29T13:00:00+05:30 - Lunch,mail
# 2026-07-29T14:00:00+05:30 - Work shallow-Scheduler
# 2026-07-29T16:00:00+05:30 - Gym
# 2026-07-29T16:30:00+05:30 - Snacks
# 2026-07-29T17:00:00+05:30 - Mop the floor
# 2026-07-29T17:30:00+05:30 - Gym
# 2026-07-29T18:30:00+05:30 - Laydown,rest
# 2026-07-29T19:00:00+05:30 - Read
# 2026-07-29T19:30:00+05:30 - Dinner
# 2026-07-29T19:50:00+05:30 - FINISH dinner
# 2026-07-29T20:30:00+05:30 - eat dinner
# 2026-07-29T21:00:00+05:30 - Plan
# 2026-07-29T23:30:00+05:30 - Plan, Diary

# %%
# View a quick summary of the data type and missing values for each column
df.info()

df.head()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 19 entries, 0 to 18
# Data columns (total 26 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   kind                        19 non-null     str
#  1   etag                        19 non-null     str
#  2   id                          19 non-null     str
#  3   status                      19 non-null     str
#  4   htmlLink                    19 non-null     str
#  5   created                     19 non-null     str
#  6   updated                     19 non-null     str
#  7   summary                     19 non-null     str
#  8   colorId                     9 non-null      str
#  9   eventLabelId                9 non-null      str
#  10  recurringEventId            19 non-null     str
#  11  iCalUID                     19 non-null     str
#  12  sequence                    19 non-null     int64
#  13  eventType                   19 non-null     str
#  14  creator.email               19 non-null     str
#  15  creator.self                19 non-null     bool
#  16  organizer.email             19 non-null     str
#  17  organizer.self              19 non-null     bool
#  18  start.dateTime              19 non-null     str
#  19  start.timeZone              19 non-null     str
#  20  end.dateTime                19 non-null     str
#  21  end.timeZone                19 non-null     str
#  22  originalStartTime.dateTime  19 non-null     str
#  23  originalStartTime.timeZone  19 non-null     str
#  24  reminders.useDefault        19 non-null     bool
#  25  reminders.overrides         2 non-null      object
# dtypes: bool(3), int64(1), object(1), str(21)
# memory usage: 3.6+ KB
#              kind                etag  \
# 0  calendar#event  "3557612008950942"
# 1  calendar#event  "3563490007267870"
# 2  calendar#event  "3557611897205950"
# 3  calendar#event  "3563337645135518"
# 4  calendar#event  "3570532160116606"
#
#                                                   id     status  \
# 0  74rm8cpm6lh3ab9lcko3ib9k6oq34b9pccrj6b9k6cs6cp...  confirmed
# 1        d9ikmds3mmqor2juqv6rglsadf_20260729T014500Z  confirmed
# 2        5jvmm9ubgubfospoas6pc6p525_20260729T020000Z  confirmed
# 3        h08r8uk70j3ehj0nab9g98gblj_20260729T023000Z  confirmed
# 4        q1msm23otaktmm8kbhc4nveb39_20260729T033000Z  confirmed
#
#                                             htmlLink  \
# 0  https://www.google.com/calendar/event?eid=NzRy...
# 1  https://www.google.com/calendar/event?eid=ZDlp...
# 2  https://www.google.com/calendar/event?eid=NWp2...
# 3  https://www.google.com/calendar/event?eid=aDA4...
# 4  https://www.google.com/calendar/event?eid=cTFt...
#
#                     created                   updated  \
# 0  2026-01-22T05:59:07.000Z  2026-05-15T00:46:44.475Z
# 1  2026-06-14T12:29:52.000Z  2026-06-18T01:10:03.633Z
# 2  2024-08-04T03:49:25.000Z  2026-05-15T00:45:48.602Z
# 3  2026-06-13T12:35:45.000Z  2026-06-17T04:00:22.567Z
# 4  2026-05-19T13:31:45.000Z  2026-07-28T19:14:40.058Z
#
#                      summary colorId                          eventLabelId  \
# 0                        Gym       4  09172d26-2d54-4826-a297-fa948bef45e0
# 1                      Pooja     NaN                                   NaN
# 2                  Breakfast      11  2a9011be-5d1c-4811-ad3c-b9fd9bf28767
# 3           Check mail, plan     NaN                                   NaN
# 4  DeepWork(no internet)-DSA     NaN                                   NaN
#
#    ...    organizer.email organizer.self             start.dateTime  \
# 0  ...  hemug67@gmail.com           True  2026-07-29T05:00:00+05:30
# 1  ...  hemug67@gmail.com           True  2026-07-29T07:15:00+05:30
# 2  ...  hemug67@gmail.com           True  2026-07-29T07:30:00+05:30
# 3  ...  hemug67@gmail.com           True  2026-07-29T08:00:00+05:30
# 4  ...  hemug67@gmail.com           True  2026-07-29T09:00:00+05:30
#
#   start.timeZone               end.dateTime  end.timeZone  \
# 0   Asia/Kolkata  2026-07-29T09:00:00+05:30  Asia/Kolkata
# 1   Asia/Kolkata  2026-07-29T07:45:00+05:30  Asia/Kolkata
# 2   Asia/Kolkata  2026-07-29T09:30:00+05:30  Asia/Kolkata
# 3   Asia/Kolkata  2026-07-29T09:00:00+05:30  Asia/Kolkata
# 4   Asia/Kolkata  2026-07-29T13:00:00+05:30  Asia/Kolkata
#
#   originalStartTime.dateTime  originalStartTime.timeZone reminders.useDefault  \
# 0  2026-07-29T05:00:00+05:30                Asia/Kolkata                 True
# 1  2026-07-29T07:15:00+05:30                Asia/Kolkata                 True
# 2  2026-07-29T07:30:00+05:30                Asia/Kolkata                 True
# 3  2026-07-29T08:00:00+05:30                Asia/Kolkata                 True
# 4  2026-07-29T09:00:00+05:30                Asia/Kolkata                False
#
#                     reminders.overrides
# 0                                   NaN
# 1                                   NaN
# 2                                   NaN
# 3                                   NaN
# 4  [{'method': 'popup', 'minutes': 10}]
#
# [5 rows x 26 columns]

# %%
df.to_csv("data/export/raw_CSV_1.csv", index=False)
